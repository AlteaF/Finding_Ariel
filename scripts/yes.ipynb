# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 18.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 17.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
# ...
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# ...
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 KB 7.4 MB/s eta 0:00:00
# ...
#   Using cached pillow-11.3.0-cp39-cp39-macosx_10_10_x86_64.whl (5.3 MB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
species = ["Fish", "Starfish", "Crab", "Black goby", "Wrasse", "Two-spotted goby", "Cod" , "Painted goby", "Sand eel", "Whiting"]

train_numbers = [9615, 18543, 5213, 3743, 965, 644, 592, 547, 285, 212]
test_numbers = [2619, 4640, 2630, 1009, 247, 227, 170, 132, 39, 49]

# %%
import matplotlib.pyplot as plt 



fig, axes = plt.subplots(1,2, figsize= (15,10))

axes[0].bar(species, train_numbers, color="red")
axes[0].set_title("Distribution of fish species in train data")
axes[0].set_ylabel("Number of fish")
axes[0].set_xlabel("Fish Species")
axes[0].set_xticklabels(species, rotation=45)


axes[1].bar(species, test_numbers, color="orange")
axes[1].set_title("Distribution of fish species in test data")
axes[1].set_ylabel("Number of fish")
axes[1].set_xlabel("Fish Species")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/88/sc4x6tp51js4ksjtccntc4wc0000gq/T/ipykernel_1798/1678292448.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(species, rotation=45)

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 KB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 14.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 13.9 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

figs, ax = plt.subplots(1, 2, figsize=(12, 5))

custom_palette = sns.color_palette("gist_rainbow", len(species))  # or "bright", "Set2", etc.


sns.barplot(x=species, y=train_numbers, ax=ax[0],palette=custom_palette)

ax[0].set_title("Distribution of fish species in train data")
ax[0].set_ylabel("Number of fish")
ax[0].set_xlabel("Fish Species")
ax[0].set_xticklabels(species, rotation=45)

sns.barplot(x=species, y=test_numbers, ax=ax[1],palette=custom_palette)

ax[1].set_title("Distribution of fish species in test data")
ax[1].set_ylabel("Number of fish")
ax[1].set_xlabel("Fish Species")
ax[1].set_xticklabels(species, rotation=45)
sns.color_palette("hls", 10, as_cmap=True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/88/sc4x6tp51js4ksjtccntc4wc0000gq/T/ipykernel_1798/2094322259.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=species, y=train_numbers, ax=ax[0],palette=custom_palette)
# /var/folders/88/sc4x6tp51js4ksjtccntc4wc0000gq/T/ipykernel_1798/2094322259.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(species, rotation=45)
# /var/folders/88/sc4x6tp51js4ksjtccntc4wc0000gq/T/ipykernel_1798/2094322259.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=species, y=test_numbers, ax=ax[1],palette=custom_palette)
# ...

# %%
import numpy as np
data = np.load("/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/cluster_files/agglomerative_clusters_dino_gray_four_classes.npz", allow_pickle=True)
image_paths = data["image_paths"]
embeddings = data["embeddings"]
print("Shape of embeddings:", embeddings.shape)
# Print 10 random paths
import random
for p in random.sample(list(image_paths), 10):
    print(p)
# Out:
# Shape of embeddings: (40359, 384)
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_07.24_22.08.33._36_3_1.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/selected_frame_751138_13_1.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_08.21_15.26.33_53_0_1.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_07.27_14.56.33_9_6_1.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_07.24_09.26.33_24_4_1.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_07.26_13.56.33_7_5_10.jpg
# /Users/alteafogh/Documents/ITU/summer/data/crop-bbs_all_cameras_train/class_all/gray/anemo_0_08.19_16.56.33_20_6_1.jpg
# ...

# %%
import numpy as np
data = np.load("/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/embeddings_files/megadescriptor_embeddings_train.npz", allow_pickle=True)
image_paths = data["image_paths"]
embeddings = data["embeddings"]
print("Shape of embeddings:", embeddings.shape)
# Out:
# Shape of embeddings: (40359, 1024)

# %%
import numpy as np
data = np.load("/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/embeddings_files/dino_embeddings_train.npz", allow_pickle=True)
image_paths = data["image_paths"]
embeddings = data["embeddings"]
print("Shape of embeddings:", embeddings.shape)
# Out:
# Shape of embeddings: (40359, 384)

# %%
import numpy as np
data = np.load("/Users/alteafogh/Documents/ITU/summer/Summer-fish/for-altea/embeddings_files/resnet_fish_embeddings_train_reshaped.npz", allow_pickle=True)
image_paths = data["image_paths"]
embeddings = data["embeddings"]
print("Shape of embeddings:", embeddings.shape)
# Out:
# Shape of embeddings: (40359, 2048)
